# %% [markdown]
# # Simple Neural Network in PyTorch [Source](https://vipulvaibhaw.com/2019/05/02/simple-neural-network-in-pytorch/)

# %% [markdown]
# ## [Install PyTorch using conda](https://pytorch.org/get-started/locally/#start-locally) if not already done

# %% [markdown]
# ## Import modules

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# Next step is to get some data with which we can play or train the neural network.
#
# We take advantage of `torch.tensor` for creating a simple data.
#
# I am taking a few data points from [iris dataset](https://archive.ics.uci.edu/ml/datasets/iris). Here,
# + X represents the petal length, petal width and sepal length,
# + Y is the sepal width.
#
# Basically for given petal length, petal width and sepal length, **can we predict sepal width? This is the problem.**
#
# xInput is the *test data* which we will pass to the neural network.

# %%
X = torch.tensor(([5.1, 3.5, 1.4], [6.7, 3.1, 4.4], [6.5, 3.2, 5.1]), dtype=torch.float) # 3 X 3 tensor
Y = torch.tensor(([0.2], [1.4], [2]), dtype=torch.float) # 3 X 1 tensor
xInput = torch.tensor(([5.9, 3, 5.1]), dtype=torch.float)

# %% [markdown]
# Let us define a simple Neural Network. *nn.Module* is a base class for all the neural network models in pytorch. Our neural network will have two fully connected or Dense or Linear layers. It will have 3 input neuron, 10 neurons (in hidden layer) and 1 output neuron.
#
# One thing to keep note of is that always think neural network as composition of functions. The thing about pytorch is that it allows us express this idea beautifully.

# %% [markdown]
# ## Define neural network in pytorch

# %%
class Neural_Network(nn.Module):

    def __init__(self):
        super(Neural_Network, self).__init__()
        self.fc1 = nn.Linear(3, 10)
        self.fc2 = nn.Linear(10, 1)

    def forward(self, x):
        x = F.sigmoid(self.fc1(x))
        x = F.sigmoid(self.fc2(x))
        return x

# %% [markdown]
# The following piece of code will help you to train and predict.

# %%
model = Neural_Network()

model.train()

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

for i in range(1000):
    optimizer.zero_grad()
    output = model(X)
    loss = F.binary_cross_entropy_with_logits(output, Y)
    print(loss)
    loss.backward()
    optimizer.step()

print(model(xInput))
# Out:
# C:\Users\agarw\Anaconda3\lib\site-packages\torch\nn\functional.py:1386: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# tensor(0.3776, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3763, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3744, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3722, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3698, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3673, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3649, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3623, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3598, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3573, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3548, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3523, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3498, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3473, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3448, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3424, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3399, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3374, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3350, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3326, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3302, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3277, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3254, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3230, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3206, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3183, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3159, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3136, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3113, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3090, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3067, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3045, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3022, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.3000, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2978, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2956, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2913, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2892, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2871, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2850, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2830, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2809, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2789, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2769, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2749, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2730, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2711, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2691, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2673, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2654, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2635, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2617, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2599, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2581, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2564, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2546, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2529, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2512, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2496, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2479, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2463, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2447, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2431, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2416, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2400, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2385, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2370, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2355, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2341, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2327, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2312, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2299, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2285, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2271, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2258, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2245, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2232, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2219, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2207, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2194, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2182, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2170, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2159, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2147, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2136, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2124, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2113, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2102, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2091, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2081, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2070, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2060, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2050, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2040, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2030, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2021, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2011, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.2002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1993, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1984, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1975, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1966, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1957, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1949, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1924, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1916, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1908, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1900, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1893, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1885, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1878, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1870, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1863, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1856, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1849, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1842, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1836, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1829, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1822, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1816, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1810, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1803, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1797, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1791, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1785, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1779, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1773, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1767, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1762, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1756, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1751, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1745, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1740, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1735, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1730, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1724, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1719, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1714, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1709, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1705, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1700, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1695, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1690, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1686, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1681, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1677, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1673, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1668, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1664, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1660, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1656, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1651, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1647, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1643, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1639, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1636, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1632, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1628, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1624, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1620, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1617, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1613, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1610, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1606, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1603, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1599, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1596, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1593, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1589, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.1586, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.